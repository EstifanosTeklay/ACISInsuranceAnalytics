# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
text_data=pd.read_csv('D:\\KAIMProjects\\ACISINSURANCEANALYTICS\\Data\\MachineLearningRating_v3.txt',delimiter='|')
# Out:
# C:\Users\EstifanosT\AppData\Local\Temp\ipykernel_19048\3050906120.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   text_data=pd.read_csv('D:\\KAIMProjects\\ACISINSURANCEANALYTICS\\Data\\MachineLearningRating_v3.txt',delimiter='|')

# %%
text_data.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
text_data.tail()
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
#         Citizenship   LegalType Title Language       Bank      AccountType  \
# 1000093          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000094          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000095          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000096          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000097          ZW  Individual    Mr  English  ABSA Bank  Savings account
#
# ...

# %% [markdown]
# ###  Data Summarization
# Summary statistics for Numerical features

# %%
text_data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
print(text_data[['TotalPremium','TotalClaims','CalculatedPremiumPerTerm','CapitalOutstanding']].describe())
# Out:
#        TotalPremium   TotalClaims  CalculatedPremiumPerTerm
# count  1.000098e+06  1.000098e+06              1.000098e+06
# mean   6.190550e+01  6.486119e+01              1.178757e+02
# std    2.302845e+02  2.384075e+03              3.997017e+02
# min   -7.825768e+02 -1.200241e+04              0.000000e+00
# 25%    0.000000e+00  0.000000e+00              3.224800e+00
# 50%    2.178333e+00  0.000000e+00              8.436900e+00
# 75%    2.192982e+01  0.000000e+00              9.000000e+01
# max    6.528260e+04  3.930921e+05              7.442217e+04

# %%
# Variability Measuures
print("variance:")
print(text_data[['TotalPremium','TotalClaims']].var())
print("Standard Deviation:")
print(text_data[['TotalPremium','TotalClaims']].std())
# Out:
# variance:
# TotalPremium    5.303096e+04
# TotalClaims     5.683812e+06
# dtype: float64
# Standard Deviation:
# TotalPremium     230.284513
# TotalClaims     2384.074695
# dtype: float64

# %% [markdown]
# ### Data Structures

# %%
# Data types checking

print(text_data.dtypes)
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
# Convert TransactionMonth and VehicleIntroDate to datetime
text_data['TransactionMonth'] = pd.to_datetime(text_data['TransactionMonth'], errors='coerce')
text_data['VehicleIntroDate'] = pd.to_datetime(text_data['VehicleIntroDate'], errors='coerce')
# Out:
# C:\Users\EstifanosT\AppData\Local\Temp\ipykernel_19048\584424686.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   text_data['VehicleIntroDate'] = pd.to_datetime(text_data['VehicleIntroDate'], errors='coerce')

# %% [markdown]
# ###  Data Quality Assesment

# %%
# Total Missing Values per Column

missing_values=text_data.isnull().sum()
missing_percentage = (text_data.isnull().sum() / len(text_data)) * 100
#print(missing_values)
#print(missing_percentage)
# Combine into a single DataFrame
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
# Display columns with missing data
print(missing_data[missing_data['Missing Values'] > 0])
# Out:
#                     Missing Values  Percentage
# Bank                        145961   14.594670
# AccountType                  40232    4.022806
# MaritalStatus                 8259    0.825819
# Gender                        9536    0.953507
# mmcode                         552    0.055195
# VehicleType                    552    0.055195
# make                           552    0.055195
# Model                          552    0.055195
# Cylinders                      552    0.055195
# cubiccapacity                  552    0.055195
# kilowatts                      552    0.055195
# bodytype                       552    0.055195
# NumberOfDoors                  552    0.055195
# VehicleIntroDate               552    0.055195
# CapitalOutstanding               2    0.000200
# NewVehicle                  153295   15.327998

# %%
# Drop Columns with excessive Missing Data threshold 50%
threshold = 50
columns_to_drop = missing_data[missing_data['Percentage'] > threshold].index
print(columns_to_drop)
# Out:
# Index(['CustomValueEstimate', 'WrittenOff', 'Rebuilt', 'Converted',
#        'CrossBorder', 'NumberOfVehiclesInFleet'],
#       dtype='object')

# %%
#  Droping Columns with more than 50% missing values
text_data.drop(columns=columns_to_drop, inplace=True)

# %%
# Impute numerical columns with median
numerical_cols = ['TotalPremium', 'TotalClaims', 'CalculatedPremiumPerTerm']
for col in numerical_cols:
    text_data[col].fillna(text_data[col].median(), inplace=True)
# Out:
# C:\Users\EstifanosT\AppData\Local\Temp\ipykernel_19048\1709445106.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   text_data[col].fillna(text_data[col].median(), inplace=True)

# %%
# Impute categorical columns with mode
categorical_cols = text_data.select_dtypes(['category']).columns
for col in categorical_cols:
    text_data[col].fillna(text_data[col].mode()[0], inplace=True)

# %%
# Removing Missing values with Smaller number of Missing Values 
text_data.isnull().sum()
# Out:
# UnderwrittenCoverID              0
# PolicyID                         0
# TransactionMonth                 0
# IsVATRegistered                  0
# Citizenship                      0
# LegalType                        0
# Title                            0
# Language                         0
# Bank                        145961
# AccountType                  40232
# MaritalStatus                 8259
# Gender                        9536
# Country                          0
# Province                         0
# PostalCode                       0
# MainCrestaZone                   0
# SubCrestaZone                    0
# ItemType                         0
# mmcode                         552
# VehicleType                    552
# RegistrationYear                 0
# make                           552
# Model                          552
# Cylinders                      552
# cubiccapacity                  552
# kilowatts                      552
# bodytype                       552
# ...

# %%
text_data[['make','Model','Cylinders','cubiccapacity','kilowatts','bodytype','NumberOfDoors']].dropna(inplace=True)
# Out:
# C:\Users\EstifanosT\AppData\Local\Temp\ipykernel_19048\3601342921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_data[['make','Model','Cylinders','cubiccapacity','kilowatts','bodytype','NumberOfDoors']].dropna(inplace=True)

# %% [markdown]
# ###  Univariate Analysis

# %%
# Distribution of Numberical Variable
# List of numerical columns
numerical_cols = ['TotalPremium', 'TotalClaims', 'CalculatedPremiumPerTerm']

# Plot histograms
text_data[numerical_cols].hist(bins=30, figsize=(15, 10), layout=(2, 2))
plt.tight_layout()
plt.show()

# %%
# List of categorical columns

selected_categorical = ['Gender', 'MaritalStatus', 'VehicleType', 'CoverCategory']

for col in selected_categorical:
    plt.figure(figsize=(4, 2))
    sns.countplot(data=text_data, x=col, order=text_data[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Computer Correlation Matrix
corr_matrix = text_data[['TotalPremium', 'TotalClaims', 'CalculatedPremiumPerTerm']].corr()
#plot hitmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
text_data.dtypes
# Out:
# UnderwrittenCoverID                  int64
# PolicyID                             int64
# TransactionMonth            datetime64[ns]
# IsVATRegistered                       bool
# Citizenship                         object
# LegalType                           object
# Title                               object
# Language                            object
# Bank                                object
# AccountType                         object
# MaritalStatus                       object
# Gender                              object
# Country                             object
# Province                            object
# PostalCode                           int64
# MainCrestaZone                      object
# SubCrestaZone                       object
# ItemType                            object
# mmcode                             float64
# VehicleType                         object
# RegistrationYear                     int64
# make                                object
# ...

# %%
# Scatter plot between TotalPremium and TotalClaims
plt.figure(figsize=(8,6))
sns.scatterplot(data=text_data,x='TotalPremium',y='TotalClaims', hue='Gender',alpha=0.6)
plt.title("Total Premium VS TotalClaims by gender")
plt.show()

# %%
# Example: Average TotalPremium and TotalClaims per PostalCode
postal_summary = text_data.groupby('PostalCode')[['TotalPremium', 'TotalClaims']].mean().reset_index()

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=postal_summary, x='PostalCode', y='TotalPremium', size='TotalClaims', legend=False, alpha=0.6)
plt.title('Average Total Premium and Total Claims by PostalCode')
plt.xlabel('PostalCode')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Data Comparision

# %%
# Average TotalPremium by Province and CoverType
province_cover = text_data.groupby(['Province', 'CoverType'])['TotalPremium'].mean().unstack()
#ploting
province_cover.plot(kind='bar',figsize=(12,8))
plt.title('Average Total Premium by Province and Cover Type')
plt.ylabel('Average Total Premium')
plt.xticks(rotation=45)
plt.legend(title='Cover Type')
plt.tight_layout()
plt.show()

# %%
# Average TotalClaims by Province and CoverType
province_cover = text_data.groupby(['Province', 'CoverType'])['TotalClaims'].mean().unstack()
#ploting
province_cover.plot(kind='bar',figsize=(12,8))
plt.title('Average Total Claims by Province and Cover Type')
plt.ylabel('Average Total Claims')
plt.xticks(rotation=45)
plt.legend(title='Cover Type')
plt.tight_layout()
plt.show()

# %%
# Extract Year and Month
text_data['YearMonth'] = text_data['TransactionMonth'].dt.to_period('M')

# Aggregate data
time_trend =text_data.groupby('YearMonth')[['TotalPremium', 'TotalClaims']].sum().reset_index()

# Convert YearMonth back to datetime for plotting
time_trend['YearMonth'] = time_trend['YearMonth'].dt.to_timestamp()

# Plotting
plt.figure(figsize=(14, 7))
sns.lineplot(data=time_trend, x='YearMonth', y='TotalPremium', label='Total Premium')
sns.lineplot(data=time_trend, x='YearMonth', y='TotalClaims', label='Total Claims')
plt.title('Monthly Total Premium and Total Claims Over Time')
plt.xlabel('Transaction Month')
plt.ylabel('Amount')
plt.legend()
plt.show()

# %%
# Box plot for Total Premium
plt.figure(figsize=(8,6))
sns.boxplot(x=text_data['TotalPremium'])
plt.title('Box plot of Total Premium')
plt.show()
#Box plot for Total Claims
plt.figure(figsize=(8,6))
sns.boxplot(x=text_data['TotalClaims'])
plt.title('Box plot of Total Claims')
plt.show()

# %%
# Log Transformation of Total Premium
text_data['LogTotalPremium']=np.log1p(text_data['TotalPremium'])

# Box plot after Transformation
plt.figure(figsize=(8,6))
sns.boxplot(x=text_data['LogTotalPremium'])
plt.title('Box plot of Log Transformed Total Premium')
plt.show()
# Out:
# C:\Users\EstifanosT\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Visualizations: Creative and Inisghtfull plots

# %%
# Total Premium VS Total Claims across different Vechile Types
plt.figure(figsize=(12,8))
sns.scatterplot(data=text_data,x='TotalPremium',y='TotalClaims',hue='VehicleType',alpha=0.6)
plt.title('Total Premium vs Total claims by vechicletype')
plt.xlabel('TotalPremium')
plt.ylabel('TotalClaims')
plt.legend(title='Vehicle Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Pivot table
claims_heatmap = text_data.pivot_table(values='TotalClaims', index='Province', columns='CoverCategory', aggfunc='sum')

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(claims_heatmap, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title('Total Claims by Province and Cover Category')
plt.xlabel('Cover Category')
plt.ylabel('Province')
plt.show()

# %%
#Distribution of TotalPremium across different Maritial Status
plt.figure(figsize=(10, 6))
sns.boxplot(data=text_data, x='MaritalStatus', y='TotalPremium')
plt.title('Distribution of Total Premium by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Total Premium')
plt.xticks(rotation=45)
plt.show()
